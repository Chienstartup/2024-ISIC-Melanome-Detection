# %% [markdown]
# <a href="https://colab.research.google.com/github/Chienstartup/ISIC_2024/blob/main/features_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.32)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 6.6 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 14.5 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-4.0.0

# %%
import optuna
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold, StratifiedGroupKFold,StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import PredefinedSplit
from tqdm import tqdm

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/Chienstartup/ISIC_2024/main/meta_data/df_train.csv')

# %% [markdown]
# <h3>Split dataset into 5 Folds</h3>

# %%
N_SPLITS = 5
gkf = GroupKFold(n_splits=N_SPLITS)
df_train["fold"] = -1
for idx, (train_idx, val_idx) in enumerate(gkf.split(df_train, df_train["target"], groups=df_train["patient_id"])):
    df_train.loc[val_idx, "fold"] = idx

# %%
feature_cols = [x for x in df_train.columns if x not in ["target", "fold", "patient_id", 'isic_id',]]

# %%
def custom_metric_binary(y_true, y_pred):
    y_hat = y_pred[:, 1] if y_pred.ndim > 1 else y_pred
    y_true_binary = y_true
    min_tpr = 0.80
    max_fpr = 1 - min_tpr

    v_gt = 1 - y_true_binary
    v_pred = 1 - y_hat
    partial_auc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    partial_auc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (partial_auc_scaled - 0.5)

    return partial_auc

# %%
def optimize_feature_selection(sampled_df, feature_cols, target_col, n_trials=10):
    X = sampled_df[feature_cols]
    y = sampled_df[target_col]
    fold = sampled_df['fold']

    best_features = []
    best_overall_score = -np.inf
    remaining_features = feature_cols.copy()

    while remaining_features:
        best_score = -np.inf
        best_feature = None

        for feature in tqdm(remaining_features, desc=f"Evaluating features (current best: {len(best_features)})"):
            current_features = best_features + [feature]

            study = optuna.create_study(direction='maximize')
            scores = []

            for _ in range(n_trials):
                study.optimize(lambda trial: lgb_objective(trial, X, y, fold, current_features), n_trials=1)
                scores.append(study.best_value)

            avg_score = np.mean(scores)

            if avg_score > best_score:
                best_score = avg_score
                best_feature = feature

        if best_score > best_overall_score:
            best_features.append(best_feature)
            remaining_features.remove(best_feature)
            best_overall_score = best_score
            print(f"\nAdded feature: {best_feature}")
            print(f"New best score: {best_score:.4f}")
            print("Current feature set:")
            for i, feat in enumerate(best_features, 1):
                print(f"{i}. {feat}")
        else:
            print(f"\nStopping: No improvement (best overall: {best_overall_score:.4f}, current best: {best_score:.4f})")
            break

    print(f"\nFinal best feature combination:")
    for i, feature in enumerate(best_features, 1):
        print(f"{i}. {feature}")
    print(f"Best overall score: {best_overall_score:.4f}")

    return best_features

def lgb_objective(trial, X, y, fold, selected_features):
    params = {
        'objective': 'binary',
        'num_class': 1,
        'n_estimators': 200,
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-3, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-3, 10.0, log=True),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 1e-1, log=True),
        'max_depth': trial.suggest_int('max_depth', 4, 8),
        'num_leaves': trial.suggest_int('num_leaves', 16, 256),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.8, 4.0),
        'device': 'cpu'
    }

    ps = PredefinedSplit(fold)

    cv_scores = []
    for train_index, val_index in ps.split():
        X_train, X_val = X.iloc[train_index][selected_features], X.iloc[val_index][selected_features]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = lgb.LGBMClassifier(**params, random_state=42)
        model.fit(X_train, y_train)

        y_pred = model.predict_proba(X_val)
        score = custom_metric_binary(y_val, y_pred)
        cv_scores.append(score)

    cv_score = np.mean(cv_scores)
    return cv_score

# %%
best_features = optimize_feature_selection(df_train, feature_cols, 'target', n_trials=1)
print("Best feature combination:", best_features)
# Out:
# Evaluating features (current best: 0):   0%|          | 0/124 [00:00<?, ?it/s][I 2024-09-11 08:35:06,226] A new study created in memory with name: no-name-c3365a5f-9447-44d9-a29a-c224a45b0118
# [I 2024-09-11 08:35:06,968] Trial 0 finished with value: 0.03088223288233165 and parameters: {'lambda_l1': 5.294003892553125, 'lambda_l2': 0.07408247868285786, 'learning_rate': 0.06168355492491374, 'max_depth': 8, 'num_leaves': 211, 'colsample_bytree': 0.8402081749780288, 'colsample_bynode': 0.8817645764858415, 'bagging_fraction': 0.9263357375313878, 'bagging_freq': 1, 'min_child_samples': 14, 'scale_pos_weight': 3.0033960674544344}. Best is trial 0 with value: 0.03088223288233165.
# Evaluating features (current best: 0):   1%|          | 1/124 [00:00<01:31,  1.34it/s][I 2024-09-11 08:35:06,979] A new study created in memory with name: no-name-e34b2e0e-bb49-42f2-9166-edb43851be4e
# [I 2024-09-11 08:35:07,479] Trial 0 finished with value: 0.090252952433932 and parameters: {'lambda_l1': 0.7393605544546851, 'lambda_l2': 0.05524641274176077, 'learning_rate': 0.030955526334358868, 'max_depth': 4, 'num_leaves': 133, 'colsample_bytree': 0.6773346206383188, 'colsample_bynode': 0.8500357200988076, 'bagging_fraction': 0.48959795334066575, 'bagging_freq': 4, 'min_child_samples': 94, 'scale_pos_weight': 1.8887003446245112}. Best is trial 0 with value: 0.090252952433932.
# Evaluating features (current best: 0):   2%|▏         | 2/124 [00:01<01:13,  1.65it/s][I 2024-09-11 08:35:07,484] A new study created in memory with name: no-name-321f26d4-85db-4711-a3be-ecd619b8a0d9
# [I 2024-09-11 08:35:08,242] Trial 0 finished with value: 0.027797819981538702 and parameters: {'lambda_l1': 0.001477068428761108, 'lambda_l2': 0.04187177029211975, 'learning_rate': 0.031603353908038624, 'max_depth': 7, 'num_leaves': 71, 'colsample_bytree': 0.5286290837946366, 'colsample_bynode': 0.4521690034688606, 'bagging_fraction': 0.5589127783555131, 'bagging_freq': 4, 'min_child_samples': 51, 'scale_pos_weight': 0.9894330489433018}. Best is trial 0 with value: 0.027797819981538702.
# Evaluating features (current best: 0):   2%|▏         | 3/124 [00:02<01:22,  1.48it/s][I 2024-09-11 08:35:08,248] A new study created in memory with name: no-name-825d0dfa-49c2-4691-a8dc-2b1b6716fb0c
# [I 2024-09-11 08:35:08,923] Trial 0 finished with value: 0.04226550751411544 and parameters: {'lambda_l1': 0.005241893354279737, 'lambda_l2': 3.0964927901668404, 'learning_rate': 0.014963947442095147, 'max_depth': 6, 'num_leaves': 140, 'colsample_bytree': 0.9702632354926026, 'colsample_bynode': 0.4904878862598571, 'bagging_fraction': 0.47874662043242794, 'bagging_freq': 3, 'min_child_samples': 56, 'scale_pos_weight': 2.9272015594736}. Best is trial 0 with value: 0.04226550751411544.
# Evaluating features (current best: 0):   3%|▎         | 4/124 [00:02<01:21,  1.47it/s][I 2024-09-11 08:35:08,928] A new study created in memory with name: no-name-e3a8aafc-19be-4f72-9f0c-f0233503e3f9
# [I 2024-09-11 08:35:09,768] Trial 0 finished with value: 0.05735198549700451 and parameters: {'lambda_l1': 0.13213302951419967, 'lambda_l2': 0.0031036222593880144, 'learning_rate': 0.02020093848410362, 'max_depth': 7, 'num_leaves': 111, 'colsample_bytree': 0.9981481771679762, 'colsample_bynode': 0.4393011932715866, 'bagging_fraction': 0.661562322012925, 'bagging_freq': 3, 'min_child_samples': 50, 'scale_pos_weight': 1.5325523329528512}. Best is trial 0 with value: 0.05735198549700451.
# Evaluating features (current best: 0):   4%|▍         | 5/124 [00:03<01:27,  1.35it/s][I 2024-09-11 08:35:09,773] A new study created in memory with name: no-name-b5724dac-add6-438e-a012-c294a2905ac0
# [I 2024-09-11 08:35:10,526] Trial 0 finished with value: 0.03608317668068992 and parameters: {'lambda_l1': 1.9450623267822191, 'lambda_l2': 0.0036663905383459527, 'learning_rate': 0.06990170895469787, 'max_depth': 6, 'num_leaves': 252, 'colsample_bytree': 0.5931987682465117, 'colsample_bynode': 0.8169797028261268, 'bagging_fraction': 0.9219002291026506, 'bagging_freq': 2, 'min_child_samples': 91, 'scale_pos_weight': 3.9432025911837068}. Best is trial 0 with value: 0.03608317668068992.
# Evaluating features (current best: 0):   5%|▍         | 6/124 [00:04<01:27,  1.34it/s][I 2024-09-11 08:35:10,532] A new study created in memory with name: no-name-c2d1d382-d061-4f8e-b178-f13fcbd9a062
# [I 2024-09-11 08:35:11,371] Trial 0 finished with value: 0.02020439321128872 and parameters: {'lambda_l1': 0.4194614322874146, 'lambda_l2': 0.20316644059432934, 'learning_rate': 0.012203589320205684, 'max_depth': 7, 'num_leaves': 98, 'colsample_bytree': 0.6996323313552606, 'colsample_bynode': 0.4458548205610467, 'bagging_fraction': 0.8470191629420933, 'bagging_freq': 3, 'min_child_samples': 54, 'scale_pos_weight': 0.9133721522725371}. Best is trial 0 with value: 0.02020439321128872.
# Evaluating features (current best: 0):   6%|▌         | 7/124 [00:05<01:31,  1.29it/s][I 2024-09-11 08:35:11,380] A new study created in memory with name: no-name-e794cbc5-c19f-4f6a-8011-99e75131148f
# [I 2024-09-11 08:35:12,725] Trial 0 finished with value: 0.02034818967164088 and parameters: {'lambda_l1': 0.0028967269045189125, 'lambda_l2': 0.05518910208139067, 'learning_rate': 0.03880952518204545, 'max_depth': 8, 'num_leaves': 46, 'colsample_bytree': 0.8531559706495948, 'colsample_bynode': 0.7761562378257012, 'bagging_fraction': 0.5822277804251702, 'bagging_freq': 4, 'min_child_samples': 17, 'scale_pos_weight': 1.9925014353552255}. Best is trial 0 with value: 0.02034818967164088.
# Evaluating features (current best: 0):   6%|▋         | 8/124 [00:06<01:51,  1.04it/s][I 2024-09-11 08:35:12,730] A new study created in memory with name: no-name-e36fcc57-ed9b-4092-a9a7-ba2bc28979c4
# [I 2024-09-11 08:35:13,703] Trial 0 finished with value: 0.07253897936376409 and parameters: {'lambda_l1': 0.0013515333790952314, 'lambda_l2': 0.016150605757408235, 'learning_rate': 0.02081022424588605, 'max_depth': 5, 'num_leaves': 220, 'colsample_bytree': 0.4859894709478513, 'colsample_bynode': 0.9064387108356319, 'bagging_fraction': 0.6895371090351243, 'bagging_freq': 4, 'min_child_samples': 36, 'scale_pos_weight': 2.0675147414814132}. Best is trial 0 with value: 0.07253897936376409.
# Evaluating features (current best: 0):   7%|▋         | 9/124 [00:07<01:51,  1.03it/s][I 2024-09-11 08:35:13,710] A new study created in memory with name: no-name-8ab1f0f5-e4b9-4097-abcd-c945f2245018
# [I 2024-09-11 08:35:14,837] Trial 0 finished with value: 0.04340992220507752 and parameters: {'lambda_l1': 0.031814617091842204, 'lambda_l2': 0.014039229586919846, 'learning_rate': 0.06305106473416017, 'max_depth': 6, 'num_leaves': 142, 'colsample_bytree': 0.4092034729751374, 'colsample_bynode': 0.6013559995404753, 'bagging_fraction': 0.9243671051334411, 'bagging_freq': 7, 'min_child_samples': 35, 'scale_pos_weight': 3.8575828270361825}. Best is trial 0 with value: 0.04340992220507752.
# Evaluating features (current best: 0):   8%|▊         | 10/124 [00:08<01:56,  1.02s/it][I 2024-09-11 08:35:14,843] A new study created in memory with name: no-name-31618207-df56-4d02-ac25-9e4f556a90bb
# [I 2024-09-11 08:35:15,539] Trial 0 finished with value: 0.02020268699091465 and parameters: {'lambda_l1': 0.10763038728031302, 'lambda_l2': 0.017140156766232165, 'learning_rate': 0.03328373214610511, 'max_depth': 5, 'num_leaves': 116, 'colsample_bytree': 0.5172895226526185, 'colsample_bynode': 0.4007633138953404, 'bagging_fraction': 0.43199793824624155, 'bagging_freq': 6, 'min_child_samples': 77, 'scale_pos_weight': 1.0426232378906635}. Best is trial 0 with value: 0.02020268699091465.
# Evaluating features (current best: 0):   9%|▉         | 11/124 [00:09<01:44,  1.09it/s][I 2024-09-11 08:35:15,543] A new study created in memory with name: no-name-061fe466-93e2-4fee-b78a-8ab07382e977
# [I 2024-09-11 08:35:16,062] Trial 0 finished with value: 0.02440286591896974 and parameters: {'lambda_l1': 0.0025273730729417636, 'lambda_l2': 0.06642422170134309, 'learning_rate': 0.07444987348176145, 'max_depth': 4, 'num_leaves': 203, 'colsample_bytree': 0.7130310747063011, 'colsample_bynode': 0.5099881188704628, 'bagging_fraction': 0.641634973782905, 'bagging_freq': 1, 'min_child_samples': 77, 'scale_pos_weight': 1.8247142662938864}. Best is trial 0 with value: 0.02440286591896974.
# Evaluating features (current best: 0):  10%|▉         | 12/124 [00:09<01:29,  1.25it/s][I 2024-09-11 08:35:16,069] A new study created in memory with name: no-name-b0eb16a0-894a-413d-b250-459f70008c92
# [I 2024-09-11 08:35:16,989] Trial 0 finished with value: 0.0845995647012159 and parameters: {'lambda_l1': 0.0033941796339190247, 'lambda_l2': 0.1893476938184988, 'learning_rate': 0.0655747666262985, 'max_depth': 7, 'num_leaves': 149, 'colsample_bytree': 0.5172777106681397, 'colsample_bynode': 0.42876514683628847, 'bagging_fraction': 0.4099630313306676, 'bagging_freq': 7, 'min_child_samples': 88, 'scale_pos_weight': 1.7931102048968866}. Best is trial 0 with value: 0.0845995647012159.
# Evaluating features (current best: 0):  10%|█         | 13/124 [00:10<01:33,  1.19it/s][I 2024-09-11 08:35:16,996] A new study created in memory with name: no-name-a062bf88-cac3-4703-b04f-5e3088b9b1f1
# [I 2024-09-11 08:35:17,779] Trial 0 finished with value: 0.06758741955959766 and parameters: {'lambda_l1': 0.05851329882293941, 'lambda_l2': 0.039024772092634996, 'learning_rate': 0.09361546772222011, 'max_depth': 4, 'num_leaves': 144, 'colsample_bytree': 0.5983901097511107, 'colsample_bynode': 0.5377132352562844, 'bagging_fraction': 0.5264406522050832, 'bagging_freq': 3, 'min_child_samples': 97, 'scale_pos_weight': 1.9355325729983666}. Best is trial 0 with value: 0.06758741955959766.
# Evaluating features (current best: 0):  11%|█▏        | 14/124 [00:11<01:30,  1.21it/s][I 2024-09-11 08:35:17,786] A new study created in memory with name: no-name-85be8f8c-4971-4d65-adda-29236948466a
# [I 2024-09-11 08:35:18,760] Trial 0 finished with value: 0.023336285056617743 and parameters: {'lambda_l1': 0.06588217018063265, 'lambda_l2': 0.006242478734082439, 'learning_rate': 0.03658669755736627, 'max_depth': 5, 'num_leaves': 250, 'colsample_bytree': 0.43778984807831395, 'colsample_bynode': 0.721013738241187, 'bagging_fraction': 0.45847087092599476, 'bagging_freq': 4, 'min_child_samples': 7, 'scale_pos_weight': 2.6003321643224258}. Best is trial 0 with value: 0.023336285056617743.
# Evaluating features (current best: 0):  12%|█▏        | 15/124 [00:12<01:35,  1.15it/s][I 2024-09-11 08:35:18,768] A new study created in memory with name: no-name-9ff6c155-2ec4-4b47-878c-aeaa57efdbf1
# [I 2024-09-11 08:35:19,719] Trial 0 finished with value: 0.0686428149411431 and parameters: {'lambda_l1': 0.15091627084170933, 'lambda_l2': 0.0035688256327670587, 'learning_rate': 0.056085189987343555, 'max_depth': 6, 'num_leaves': 49, 'colsample_bytree': 0.6953020972372119, 'colsample_bynode': 0.5895717063859, 'bagging_fraction': 0.6293929302445938, 'bagging_freq': 3, 'min_child_samples': 50, 'scale_pos_weight': 3.143670456500855}. Best is trial 0 with value: 0.0686428149411431.
# Evaluating features (current best: 0):  13%|█▎        | 16/124 [00:13<01:36,  1.11it/s][I 2024-09-11 08:35:19,723] A new study created in memory with name: no-name-9f2a1126-2076-495d-a51c-be50a52a42bc
# [I 2024-09-11 08:35:20,614] Trial 0 finished with value: 0.025779430068346636 and parameters: {'lambda_l1': 0.803676285077623, 'lambda_l2': 0.051099690808387485, 'learning_rate': 0.011105232135963752, 'max_depth': 8, 'num_leaves': 200, 'colsample_bytree': 0.44577167554705743, 'colsample_bynode': 0.7667730223879223, 'bagging_fraction': 0.7669756565370073, 'bagging_freq': 5, 'min_child_samples': 67, 'scale_pos_weight': 1.4478287068707811}. Best is trial 0 with value: 0.025779430068346636.
# Evaluating features (current best: 0):  14%|█▎        | 17/124 [00:14<01:35,  1.12it/s][I 2024-09-11 08:35:20,619] A new study created in memory with name: no-name-91773141-3ae3-420e-9963-f1f564f19548
# [I 2024-09-11 08:35:21,143] Trial 0 finished with value: 0.03487576871123539 and parameters: {'lambda_l1': 0.020739000576119906, 'lambda_l2': 0.04719870765443748, 'learning_rate': 0.0529989230934134, 'max_depth': 4, 'num_leaves': 175, 'colsample_bytree': 0.7093150149301972, 'colsample_bynode': 0.8914429190716262, 'bagging_fraction': 0.515855153891686, 'bagging_freq': 3, 'min_child_samples': 79, 'scale_pos_weight': 1.9800250917867777}. Best is trial 0 with value: 0.03487576871123539.
# Evaluating features (current best: 0):  15%|█▍        | 18/124 [00:14<01:23,  1.27it/s][I 2024-09-11 08:35:21,148] A new study created in memory with name: no-name-999fda48-2754-45bb-b25c-6632d09b6102
# [I 2024-09-11 08:35:21,679] Trial 0 finished with value: 0.03763991890783527 and parameters: {'lambda_l1': 0.49737387881057354, 'lambda_l2': 0.7271020532208247, 'learning_rate': 0.03467911959875348, 'max_depth': 4, 'num_leaves': 99, 'colsample_bytree': 0.6013392825272929, 'colsample_bynode': 0.6586799884812826, 'bagging_fraction': 0.49472413484636435, 'bagging_freq': 4, 'min_child_samples': 47, 'scale_pos_weight': 3.5478333230132897}. Best is trial 0 with value: 0.03763991890783527.
# Evaluating features (current best: 0):  15%|█▌        | 19/124 [00:15<01:14,  1.41it/s][I 2024-09-11 08:35:21,685] A new study created in memory with name: no-name-ffcd79c5-867b-4931-9c76-6534106134ec
# [I 2024-09-11 08:35:22,518] Trial 0 finished with value: 0.0720575431933023 and parameters: {'lambda_l1': 2.773567037814876, 'lambda_l2': 1.433594253414687, 'learning_rate': 0.012368610486443863, 'max_depth': 8, 'num_leaves': 40, 'colsample_bytree': 0.5132548734395289, 'colsample_bynode': 0.7204813363540181, 'bagging_fraction': 0.9347196027297004, 'bagging_freq': 5, 'min_child_samples': 5, 'scale_pos_weight': 2.9573587798588212}. Best is trial 0 with value: 0.0720575431933023.
# Evaluating features (current best: 0):  16%|█▌        | 20/124 [00:16<01:17,  1.33it/s][I 2024-09-11 08:35:22,522] A new study created in memory with name: no-name-11f7b515-1243-4b5c-a86d-4d13d7926e31
# [I 2024-09-11 08:35:23,094] Trial 0 finished with value: 0.04130867381779632 and parameters: {'lambda_l1': 0.0024325809494656295, 'lambda_l2': 0.3418187602582723, 'learning_rate': 0.06464689583169839, 'max_depth': 4, 'num_leaves': 239, 'colsample_bytree': 0.42176100481823425, 'colsample_bynode': 0.7848492342950308, 'bagging_fraction': 0.8825218805538665, 'bagging_freq': 2, 'min_child_samples': 73, 'scale_pos_weight': 0.8679208344111906}. Best is trial 0 with value: 0.04130867381779632.
# Evaluating features (current best: 0):  17%|█▋        | 21/124 [00:16<01:11,  1.43it/s][I 2024-09-11 08:35:23,099] A new study created in memory with name: no-name-9f9bd72a-803e-4654-847f-301a818be2ad
# [I 2024-09-11 08:35:23,941] Trial 0 finished with value: 0.019388142411466927 and parameters: {'lambda_l1': 0.0013556406821192133, 'lambda_l2': 0.0018657512120052817, 'learning_rate': 0.012997513486981688, 'max_depth': 8, 'num_leaves': 28, 'colsample_bytree': 0.6633023972169061, 'colsample_bynode': 0.4888424928027796, 'bagging_fraction': 0.9724528395830951, 'bagging_freq': 7, 'min_child_samples': 38, 'scale_pos_weight': 3.7743671596414554}. Best is trial 0 with value: 0.019388142411466927.
# Evaluating features (current best: 0):  18%|█▊        | 22/124 [00:17<01:15,  1.35it/s][I 2024-09-11 08:35:23,947] A new study created in memory with name: no-name-ab938f89-6231-42e2-b2aa-518ab8dc5e93
# [I 2024-09-11 08:35:24,606] Trial 0 finished with value: 0.06670427214658124 and parameters: {'lambda_l1': 0.053201556287241686, 'lambda_l2': 0.0036371014005228005, 'learning_rate': 0.05214175138734231, 'max_depth': 6, 'num_leaves': 110, 'colsample_bytree': 0.7056217678588261, 'colsample_bynode': 0.6821927423228773, 'bagging_fraction': 0.6255405500132358, 'bagging_freq': 7, 'min_child_samples': 87, 'scale_pos_weight': 1.368752336017683}. Best is trial 0 with value: 0.06670427214658124.
# Evaluating features (current best: 0):  19%|█▊        | 23/124 [00:18<01:12,  1.39it/s][I 2024-09-11 08:35:24,610] A new study created in memory with name: no-name-16d87f76-7fbf-4f5b-9c87-e8a6da05b084
# [I 2024-09-11 08:35:25,540] Trial 0 finished with value: 0.08068138081931155 and parameters: {'lambda_l1': 0.13909100071506983, 'lambda_l2': 0.11727065404127827, 'learning_rate': 0.015110936437337073, 'max_depth': 8, 'num_leaves': 231, 'colsample_bytree': 0.9688820256822777, 'colsample_bynode': 0.7373281868073467, 'bagging_fraction': 0.6533928744381448, 'bagging_freq': 4, 'min_child_samples': 24, 'scale_pos_weight': 0.8181933812258173}. Best is trial 0 with value: 0.08068138081931155.
# Evaluating features (current best: 0):  19%|█▉        | 24/124 [00:19<01:18,  1.28it/s][I 2024-09-11 08:35:25,545] A new study created in memory with name: no-name-10a47595-3712-40f7-b37c-4b8a8c0f3c6f
# [I 2024-09-11 08:35:26,075] Trial 0 finished with value: 0.07005437777918272 and parameters: {'lambda_l1': 0.15993237872412738, 'lambda_l2': 0.43110484527583043, 'learning_rate': 0.020780242830908454, 'max_depth': 4, 'num_leaves': 102, 'colsample_bytree': 0.8951413765903815, 'colsample_bynode': 0.6614155975856437, 'bagging_fraction': 0.8255551181604028, 'bagging_freq': 6, 'min_child_samples': 75, 'scale_pos_weight': 1.3858758318870783}. Best is trial 0 with value: 0.07005437777918272.
# Evaluating features (current best: 0):  20%|██        | 25/124 [00:19<01:10,  1.41it/s][I 2024-09-11 08:35:26,079] A new study created in memory with name: no-name-15426ed9-3ffb-4579-b004-e2bfdaea8a29
# [I 2024-09-11 08:35:26,839] Trial 0 finished with value: 0.030042255717346544 and parameters: {'lambda_l1': 0.0030884978815253717, 'lambda_l2': 0.04033680582946757, 'learning_rate': 0.0582655876759396, 'max_depth': 7, 'num_leaves': 120, 'colsample_bytree': 0.8279369326405267, 'colsample_bynode': 0.7143191588041066, 'bagging_fraction': 0.7717794240052751, 'bagging_freq': 1, 'min_child_samples': 24, 'scale_pos_weight': 1.9733488236799936}. Best is trial 0 with value: 0.030042255717346544.
# Evaluating features (current best: 0):  21%|██        | 26/124 [00:20<01:11,  1.38it/s][I 2024-09-11 08:35:26,842] A new study created in memory with name: no-name-0eb24e57-7e8d-4ad9-9ec1-270427eeddd8
# [I 2024-09-11 08:35:27,463] Trial 0 finished with value: 0.026035272983131234 and parameters: {'lambda_l1': 0.027433339615336033, 'lambda_l2': 2.9232498790470434, 'learning_rate': 0.01847432185226987, 'max_depth': 5, 'num_leaves': 198, 'colsample_bytree': 0.7892577889217265, 'colsample_bynode': 0.8726468458718541, 'bagging_fraction': 0.805615753672391, 'bagging_freq': 4, 'min_child_samples': 96, 'scale_pos_weight': 2.171424980044174}. Best is trial 0 with value: 0.026035272983131234.
# Evaluating features (current best: 0):  22%|██▏       | 27/124 [00:21<01:07,  1.44it/s][I 2024-09-11 08:35:27,470] A new study created in memory with name: no-name-7757c700-3e5e-4e7f-8147-76e8de43ee19
# [I 2024-09-11 08:35:28,241] Trial 0 finished with value: 0.015251954841960482 and parameters: {'lambda_l1': 0.008050709397887042, 'lambda_l2': 0.1528304221464981, 'learning_rate': 0.07942666134355827, 'max_depth': 7, 'num_leaves': 139, 'colsample_bytree': 0.8753202552931898, 'colsample_bynode': 0.8821844655114651, 'bagging_fraction': 0.6751368864863767, 'bagging_freq': 7, 'min_child_samples': 64, 'scale_pos_weight': 2.2437475269969633}. Best is trial 0 with value: 0.015251954841960482.
# Evaluating features (current best: 0):  23%|██▎       | 28/124 [00:22<01:09,  1.39it/s][I 2024-09-11 08:35:28,245] A new study created in memory with name: no-name-33bf4e65-dd77-4de2-bd8f-a386185c6193
# [I 2024-09-11 08:35:29,034] Trial 0 finished with value: 0.025207084956633808 and parameters: {'lambda_l1': 0.0068361812854479224, 'lambda_l2': 2.3182224551581143, 'learning_rate': 0.0574098602337152, 'max_depth': 8, 'num_leaves': 120, 'colsample_bytree': 0.894017473808298, 'colsample_bynode': 0.61085619156971, 'bagging_fraction': 0.4731352304399866, 'bagging_freq': 6, 'min_child_samples': 57, 'scale_pos_weight': 3.3557833485729027}. Best is trial 0 with value: 0.025207084956633808.
# Evaluating features (current best: 0):  23%|██▎       | 29/124 [00:22<01:10,  1.35it/s][I 2024-09-11 08:35:29,039] A new study created in memory with name: no-name-e70a001d-8f80-46e2-8067-f9f54aff7826
# [I 2024-09-11 08:35:29,601] Trial 0 finished with value: 0.03197841512890521 and parameters: {'lambda_l1': 7.761357094529854, 'lambda_l2': 0.14824468602319177, 'learning_rate': 0.024022229525086508, 'max_depth': 8, 'num_leaves': 239, 'colsample_bytree': 0.578760169855668, 'colsample_bynode': 0.6937731893756602, 'bagging_fraction': 0.9400792836761414, 'bagging_freq': 3, 'min_child_samples': 42, 'scale_pos_weight': 1.142861337223971}. Best is trial 0 with value: 0.03197841512890521.
# Evaluating features (current best: 0):  24%|██▍       | 30/124 [00:23<01:04,  1.45it/s][I 2024-09-11 08:35:29,607] A new study created in memory with name: no-name-8bc7ac6b-e3fb-4986-96b1-865bee150736
# [I 2024-09-11 08:35:30,517] Trial 0 finished with value: 0.024275133552349216 and parameters: {'lambda_l1': 5.1565949960486135, 'lambda_l2': 2.4189294590088286, 'learning_rate': 0.06986417716347726, 'max_depth': 7, 'num_leaves': 59, 'colsample_bytree': 0.9318934120481467, 'colsample_bynode': 0.5623974559119203, 'bagging_fraction': 0.741289557153494, 'bagging_freq': 2, 'min_child_samples': 47, 'scale_pos_weight': 1.7565302992912875}. Best is trial 0 with value: 0.024275133552349216.
# Evaluating features (current best: 0):  25%|██▌       | 31/124 [00:24<01:10,  1.32it/s][I 2024-09-11 08:35:30,522] A new study created in memory with name: no-name-0a48f9f0-88b3-4070-bd59-cf1e2e80c971
# [I 2024-09-11 08:35:31,452] Trial 0 finished with value: 0.06666139647616495 and parameters: {'lambda_l1': 0.00346293854676828, 'lambda_l2': 0.9738960958288417, 'learning_rate': 0.07716783966225568, 'max_depth': 5, 'num_leaves': 172, 'colsample_bytree': 0.4987295867206697, 'colsample_bynode': 0.41422816020628056, 'bagging_fraction': 0.6574428800073422, 'bagging_freq': 6, 'min_child_samples': 71, 'scale_pos_weight': 3.1811491839312405}. Best is trial 0 with value: 0.06666139647616495.
# Evaluating features (current best: 0):  26%|██▌       | 32/124 [00:25<01:14,  1.23it/s][I 2024-09-11 08:35:31,458] A new study created in memory with name: no-name-ab58a45c-8380-49ca-a03e-fb151957cf20
# [I 2024-09-11 08:35:32,817] Trial 0 finished with value: 0.03153827364058874 and parameters: {'lambda_l1': 0.3976913574077803, 'lambda_l2': 0.16211497674090594, 'learning_rate': 0.05985973137419307, 'max_depth': 8, 'num_leaves': 240, 'colsample_bytree': 0.5475466532261974, 'colsample_bynode': 0.6518534809180392, 'bagging_fraction': 0.42564730594754163, 'bagging_freq': 1, 'min_child_samples': 27, 'scale_pos_weight': 0.8653715418483003}. Best is trial 0 with value: 0.03153827364058874.
# Evaluating features (current best: 0):  27%|██▋       | 33/124 [00:26<01:28,  1.02it/s][I 2024-09-11 08:35:32,824] A new study created in memory with name: no-name-be98f340-04ee-43ea-9315-60b2d7d472e4
# [I 2024-09-11 08:35:33,627] Trial 0 finished with value: 0.04935891920797147 and parameters: {'lambda_l1': 0.0013411178461508948, 'lambda_l2': 0.13415443590988424, 'learning_rate': 0.05657961640976647, 'max_depth': 7, 'num_leaves': 158, 'colsample_bytree': 0.9552609583037786, 'colsample_bynode': 0.7520269005061246, 'bagging_fraction': 0.6345828122374123, 'bagging_freq': 3, 'min_child_samples': 67, 'scale_pos_weight': 2.1127820822780494}. Best is trial 0 with value: 0.04935891920797147.
# Evaluating features (current best: 0):  27%|██▋       | 34/124 [00:27<01:23,  1.08it/s][I 2024-09-11 08:35:33,632] A new study created in memory with name: no-name-33977bfb-b884-472a-9366-391fc8ab7215
# [I 2024-09-11 08:35:34,504] Trial 0 finished with value: 0.026076106190106807 and parameters: {'lambda_l1': 0.23812849459500646, 'lambda_l2': 0.026230844037574738, 'learning_rate': 0.015213001073246309, 'max_depth': 8, 'num_leaves': 184, 'colsample_bytree': 0.5055151169902045, 'colsample_bynode': 0.6244508705667089, 'bagging_fraction': 0.7470756141103199, 'bagging_freq': 1, 'min_child_samples': 8, 'scale_pos_weight': 2.941852012074964}. Best is trial 0 with value: 0.026076106190106807.
# Evaluating features (current best: 0):  28%|██▊       | 35/124 [00:28<01:21,  1.10it/s][I 2024-09-11 08:35:34,508] A new study created in memory with name: no-name-51e1e535-f5a1-4404-8a79-8395e1afc39a
# [I 2024-09-11 08:35:35,023] Trial 0 finished with value: 0.07070613542339636 and parameters: {'lambda_l1': 0.03210291869037005, 'lambda_l2': 0.2770518473726317, 'learning_rate': 0.0130670871518429, 'max_depth': 4, 'num_leaves': 217, 'colsample_bytree': 0.9823823723005373, 'colsample_bynode': 0.4810698442248032, 'bagging_fraction': 0.5097124044143712, 'bagging_freq': 6, 'min_child_samples': 29, 'scale_pos_weight': 3.6603037164238206}. Best is trial 0 with value: 0.07070613542339636.
# Evaluating features (current best: 0):  29%|██▉       | 36/124 [00:28<01:09,  1.26it/s][I 2024-09-11 08:35:35,028] A new study created in memory with name: no-name-e10baca9-6f86-4e7d-85c8-b2a5504f050d
# [I 2024-09-11 08:35:35,674] Trial 0 finished with value: 0.042341688633751436 and parameters: {'lambda_l1': 0.14848345800471693, 'lambda_l2': 0.15958553319304633, 'learning_rate': 0.030701704991903847, 'max_depth': 5, 'num_leaves': 245, 'colsample_bytree': 0.5242421121299374, 'colsample_bynode': 0.5035100132745207, 'bagging_fraction': 0.7780327455836396, 'bagging_freq': 7, 'min_child_samples': 26, 'scale_pos_weight': 2.868461875087876}. Best is trial 0 with value: 0.042341688633751436.
# Evaluating features (current best: 0):  30%|██▉       | 37/124 [00:29<01:05,  1.33it/s][I 2024-09-11 08:35:35,679] A new study created in memory with name: no-name-55c79043-025e-417c-afe1-3efdb66b3c3f
# [I 2024-09-11 08:35:36,402] Trial 0 finished with value: 0.029952100043180628 and parameters: {'lambda_l1': 0.04612577238697121, 'lambda_l2': 8.269693738163806, 'learning_rate': 0.08077015663200404, 'max_depth': 5, 'num_leaves': 103, 'colsample_bytree': 0.534641241204711, 'colsample_bynode': 0.8438302705526375, 'bagging_fraction': 0.7860108566170123, 'bagging_freq': 5, 'min_child_samples': 8, 'scale_pos_weight': 0.9586925579492726}. Best is trial 0 with value: 0.029952100043180628.
# Evaluating features (current best: 0):  31%|███       | 38/124 [00:30<01:04,  1.34it/s][I 2024-09-11 08:35:36,407] A new study created in memory with name: no-name-37e5fcbd-d003-4adc-9f7b-cd456d53b4dd
# [I 2024-09-11 08:35:37,081] Trial 0 finished with value: 0.0397589225959459 and parameters: {'lambda_l1': 0.27565249644037415, 'lambda_l2': 0.012954211445601145, 'learning_rate': 0.017163724135161037, 'max_depth': 6, 'num_leaves': 162, 'colsample_bytree': 0.7415486555492286, 'colsample_bynode': 0.6262359066294051, 'bagging_fraction': 0.5701072213685958, 'bagging_freq': 7, 'min_child_samples': 81, 'scale_pos_weight': 2.0460915625790435}. Best is trial 0 with value: 0.0397589225959459.
# Evaluating features (current best: 0):  31%|███▏      | 39/124 [00:30<01:01,  1.38it/s][I 2024-09-11 08:35:37,088] A new study created in memory with name: no-name-db9096ed-7e87-4036-afc3-f16cbea7f2ad
# [I 2024-09-11 08:35:38,006] Trial 0 finished with value: 0.0460622097888206 and parameters: {'lambda_l1': 0.08887075698037887, 'lambda_l2': 0.04550244952439834, 'learning_rate': 0.01051686722347363, 'max_depth': 8, 'num_leaves': 32, 'colsample_bytree': 0.9138389402040433, 'colsample_bynode': 0.5976897147857319, 'bagging_fraction': 0.6481252419518525, 'bagging_freq': 2, 'min_child_samples': 64, 'scale_pos_weight': 1.8305933124264901}. Best is trial 0 with value: 0.0460622097888206.
# Evaluating features (current best: 0):  32%|███▏      | 40/124 [00:31<01:05,  1.27it/s][I 2024-09-11 08:35:38,012] A new study created in memory with name: no-name-4ccd9014-d978-401c-b7ef-3628a41fd768
# [I 2024-09-11 08:35:38,759] Trial 0 finished with value: 0.05919774818186756 and parameters: {'lambda_l1': 0.4000301730373209, 'lambda_l2': 0.003563425390118825, 'learning_rate': 0.03311136655619828, 'max_depth': 6, 'num_leaves': 102, 'colsample_bytree': 0.4975977995078066, 'colsample_bynode': 0.7915491591117232, 'bagging_fraction': 0.7107179929939443, 'bagging_freq': 6, 'min_child_samples': 57, 'scale_pos_weight': 2.3175266838240884}. Best is trial 0 with value: 0.05919774818186756.
# Evaluating features (current best: 0):  33%|███▎      | 41/124 [00:32<01:04,  1.29it/s][I 2024-09-11 08:35:38,763] A new study created in memory with name: no-name-1c1e77a8-8fd5-4462-be8a-3313b3e24972
# [I 2024-09-11 08:35:39,643] Trial 0 finished with value: 0.05201949851956615 and parameters: {'lambda_l1': 0.8786786545447107, 'lambda_l2': 0.9819302750395946, 'learning_rate': 0.0577939175207457, 'max_depth': 7, 'num_leaves': 197, 'colsample_bytree': 0.671190328010526, 'colsample_bynode': 0.5053739777104189, 'bagging_fraction': 0.7308686385402651, 'bagging_freq': 5, 'min_child_samples': 43, 'scale_pos_weight': 1.0588911451967888}. Best is trial 0 with value: 0.05201949851956615.
# Evaluating features (current best: 0):  34%|███▍      | 42/124 [00:33<01:06,  1.24it/s][I 2024-09-11 08:35:39,649] A new study created in memory with name: no-name-3f0aa252-edcc-4bf4-b367-32773ded3374
# [I 2024-09-11 08:35:40,527] Trial 0 finished with value: 0.07131127813256076 and parameters: {'lambda_l1': 0.11725293886796055, 'lambda_l2': 0.07667276366303183, 'learning_rate': 0.09065528017465746, 'max_depth': 7, 'num_leaves': 222, 'colsample_bytree': 0.6018251853804811, 'colsample_bynode': 0.5848828956219558, 'bagging_fraction': 0.43765282460255844, 'bagging_freq': 3, 'min_child_samples': 17, 'scale_pos_weight': 2.0765693030263437}. Best is trial 0 with value: 0.07131127813256076.
# Evaluating features (current best: 0):  35%|███▍      | 43/124 [00:34<01:07,  1.20it/s][I 2024-09-11 08:35:40,532] A new study created in memory with name: no-name-0bbde73e-ed6c-46c1-afc7-563ce61ef7ff
# [I 2024-09-11 08:35:41,384] Trial 0 finished with value: 0.03318364242605989 and parameters: {'lambda_l1': 0.628385285399855, 'lambda_l2': 1.1717061298851816, 'learning_rate': 0.027110894295967657, 'max_depth': 8, 'num_leaves': 23, 'colsample_bytree': 0.9794834750232759, 'colsample_bynode': 0.8342180566560775, 'bagging_fraction': 0.8085635704765666, 'bagging_freq': 7, 'min_child_samples': 93, 'scale_pos_weight': 1.4827113101243357}. Best is trial 0 with value: 0.03318364242605989.
# Evaluating features (current best: 0):  35%|███▌      | 44/124 [00:35<01:07,  1.19it/s][I 2024-09-11 08:35:41,389] A new study created in memory with name: no-name-1f6e3323-c7fa-4d93-83c6-2f611d0e9fcd
# [I 2024-09-11 08:35:42,069] Trial 0 finished with value: 0.03333011253864214 and parameters: {'lambda_l1': 0.025087714591632167, 'lambda_l2': 0.001114834602870191, 'learning_rate': 0.03184020320910894, 'max_depth': 6, 'num_leaves': 81, 'colsample_bytree': 0.6316569320940868, 'colsample_bynode': 0.9771665220758164, 'bagging_fraction': 0.7244332631619501, 'bagging_freq': 4, 'min_child_samples': 97, 'scale_pos_weight': 3.900557612218111}. Best is trial 0 with value: 0.03333011253864214.
# Evaluating features (current best: 0):  36%|███▋      | 45/124 [00:35<01:02,  1.26it/s][I 2024-09-11 08:35:42,074] A new study created in memory with name: no-name-6c4a815a-f6f6-4d6a-94c9-29361149243a
# [I 2024-09-11 08:35:42,604] Trial 0 finished with value: 0.02030409230034285 and parameters: {'lambda_l1': 2.500392897510483, 'lambda_l2': 2.8901145781347384, 'learning_rate': 0.06774911925482942, 'max_depth': 4, 'num_leaves': 127, 'colsample_bytree': 0.4256036070283604, 'colsample_bynode': 0.9277262503125451, 'bagging_fraction': 0.7900630829089059, 'bagging_freq': 1, 'min_child_samples': 68, 'scale_pos_weight': 2.73949252549998}. Best is trial 0 with value: 0.02030409230034285.
# Evaluating features (current best: 0):  37%|███▋      | 46/124 [00:36<00:55,  1.40it/s][I 2024-09-11 08:35:42,610] A new study created in memory with name: no-name-78c4c924-f011-4119-be4c-07c986cc0a19
# [I 2024-09-11 08:35:43,406] Trial 0 finished with value: 0.018500988769212783 and parameters: {'lambda_l1': 0.15217559210456158, 'lambda_l2': 0.0037254787052033987, 'learning_rate': 0.028905456306567826, 'max_depth': 5, 'num_leaves': 203, 'colsample_bytree': 0.9071827241112865, 'colsample_bynode': 0.9526681124524653, 'bagging_fraction': 0.41940897738823435, 'bagging_freq': 7, 'min_child_samples': 55, 'scale_pos_weight': 2.437627636226417}. Best is trial 0 with value: 0.018500988769212783.
# Evaluating features (current best: 0):  38%|███▊      | 47/124 [00:37<00:57,  1.35it/s][I 2024-09-11 08:35:43,411] A new study created in memory with name: no-name-44bb61eb-ebfc-4257-91d6-c805fd02fcee
# [I 2024-09-11 08:35:44,074] Trial 0 finished with value: 0.03249745709558384 and parameters: {'lambda_l1': 9.911115787385302, 'lambda_l2': 0.0015841885991485854, 'learning_rate': 0.012125082116547902, 'max_depth': 8, 'num_leaves': 72, 'colsample_bytree': 0.4726101917646985, 'colsample_bynode': 0.4807500528592565, 'bagging_fraction': 0.4833459096787873, 'bagging_freq': 3, 'min_child_samples': 13, 'scale_pos_weight': 2.8344787856148432}. Best is trial 0 with value: 0.03249745709558384.
# Evaluating features (current best: 0):  39%|███▊      | 48/124 [00:37<00:54,  1.39it/s][I 2024-09-11 08:35:44,082] A new study created in memory with name: no-name-96e6b4e4-1da9-470c-88f0-2ca39680911e
# [I 2024-09-11 08:35:44,935] Trial 0 finished with value: 0.0408004035189485 and parameters: {'lambda_l1': 3.820600306894755, 'lambda_l2': 0.15794125879734078, 'learning_rate': 0.01735853499694842, 'max_depth': 5, 'num_leaves': 56, 'colsample_bytree': 0.4350796782768869, 'colsample_bynode': 0.8780813387247597, 'bagging_fraction': 0.5279657469892189, 'bagging_freq': 5, 'min_child_samples': 28, 'scale_pos_weight': 2.3920258140353754}. Best is trial 0 with value: 0.0408004035189485.
# Evaluating features (current best: 0):  40%|███▉      | 49/124 [00:38<00:57,  1.31it/s][I 2024-09-11 08:35:44,941] A new study created in memory with name: no-name-dde50be6-70af-4da6-add2-c410809e28de
# [I 2024-09-11 08:35:45,958] Trial 0 finished with value: 0.024396307243546737 and parameters: {'lambda_l1': 0.7548850223065661, 'lambda_l2': 0.001269602235509654, 'learning_rate': 0.035677096789611375, 'max_depth': 5, 'num_leaves': 201, 'colsample_bytree': 0.7056434624164366, 'colsample_bynode': 0.470816511974255, 'bagging_fraction': 0.6714198908264, 'bagging_freq': 3, 'min_child_samples': 61, 'scale_pos_weight': 3.2930466731130847}. Best is trial 0 with value: 0.024396307243546737.
# Evaluating features (current best: 0):  40%|████      | 50/124 [00:39<01:02,  1.19it/s][I 2024-09-11 08:35:45,965] A new study created in memory with name: no-name-2b2832d3-6f85-4b46-ba38-faa23ef51338
# [I 2024-09-11 08:35:47,075] Trial 0 finished with value: 0.025109669282366708 and parameters: {'lambda_l1': 0.10712588128682093, 'lambda_l2': 3.557519162443668, 'learning_rate': 0.09227537683662246, 'max_depth': 8, 'num_leaves': 44, 'colsample_bytree': 0.5572877924661694, 'colsample_bynode': 0.9411674551272337, 'bagging_fraction': 0.8553002437968579, 'bagging_freq': 2, 'min_child_samples': 10, 'scale_pos_weight': 3.9916125691377866}. Best is trial 0 with value: 0.025109669282366708.
# Evaluating features (current best: 0):  41%|████      | 51/124 [00:40<01:07,  1.08it/s][I 2024-09-11 08:35:47,080] A new study created in memory with name: no-name-e68ee6d5-aac3-4a19-a7ee-38b467c942e0
# [I 2024-09-11 08:35:47,802] Trial 0 finished with value: 0.026437338847136282 and parameters: {'lambda_l1': 0.004507650757340691, 'lambda_l2': 4.734783416245254, 'learning_rate': 0.02435508868003075, 'max_depth': 6, 'num_leaves': 230, 'colsample_bytree': 0.8608107264821213, 'colsample_bynode': 0.852625330074154, 'bagging_fraction': 0.7523706170117841, 'bagging_freq': 1, 'min_child_samples': 27, 'scale_pos_weight': 3.437634682086112}. Best is trial 0 with value: 0.026437338847136282.
# Evaluating features (current best: 0):  42%|████▏     | 52/124 [00:41<01:02,  1.16it/s][I 2024-09-11 08:35:47,807] A new study created in memory with name: no-name-5fe47957-5762-46b3-97fc-45a546606bb0
# [I 2024-09-11 08:35:48,813] Trial 0 finished with value: 0.026910862857928035 and parameters: {'lambda_l1': 0.011400152510848383, 'lambda_l2': 0.5140240007604359, 'learning_rate': 0.023144636255321403, 'max_depth': 8, 'num_leaves': 137, 'colsample_bytree': 0.8210372992923696, 'colsample_bynode': 0.5400114244313449, 'bagging_fraction': 0.5154333759331191, 'bagging_freq': 1, 'min_child_samples': 5, 'scale_pos_weight': 3.536042112850434}. Best is trial 0 with value: 0.026910862857928035.
# Evaluating features (current best: 0):  43%|████▎     | 53/124 [00:42<01:04,  1.10it/s][I 2024-09-11 08:35:48,818] A new study created in memory with name: no-name-2e5f7faf-175c-483b-af86-29eec982dc9c
# [I 2024-09-11 08:35:49,592] Trial 0 finished with value: 0.04101718307506757 and parameters: {'lambda_l1': 0.0031634171595104066, 'lambda_l2': 0.0021581674940004156, 'learning_rate': 0.02715661023693668, 'max_depth': 6, 'num_leaves': 189, 'colsample_bytree': 0.8690327008677632, 'colsample_bynode': 0.8789009274442496, 'bagging_fraction': 0.9513907297885015, 'bagging_freq': 3, 'min_child_samples': 62, 'scale_pos_weight': 3.8874322744546728}. Best is trial 0 with value: 0.04101718307506757.
# Evaluating features (current best: 0):  44%|████▎     | 54/124 [00:43<01:00,  1.15it/s][I 2024-09-11 08:35:49,597] A new study created in memory with name: no-name-1ba88607-034c-457e-a15c-bce4cfccab93
# [I 2024-09-11 08:35:50,232] Trial 0 finished with value: 0.04522818859529402 and parameters: {'lambda_l1': 0.9391279078996101, 'lambda_l2': 2.9888343995694395, 'learning_rate': 0.05928209823166211, 'max_depth': 5, 'num_leaves': 103, 'colsample_bytree': 0.6616958877691353, 'colsample_bynode': 0.43444495653605464, 'bagging_fraction': 0.5664440402456515, 'bagging_freq': 2, 'min_child_samples': 75, 'scale_pos_weight': 1.4485070194203846}. Best is trial 0 with value: 0.04522818859529402.
# Evaluating features (current best: 0):  44%|████▍     | 55/124 [00:44<00:55,  1.25it/s][I 2024-09-11 08:35:50,238] A new study created in memory with name: no-name-1f6fb720-0b0c-4872-9e58-02c0638cd570
# [I 2024-09-11 08:35:51,283] Trial 0 finished with value: 0.0290698276501323 and parameters: {'lambda_l1': 0.4583771002822522, 'lambda_l2': 0.11717009986480374, 'learning_rate': 0.09385104689365047, 'max_depth': 8, 'num_leaves': 77, 'colsample_bytree': 0.9972412084492507, 'colsample_bynode': 0.4815634169496306, 'bagging_fraction': 0.6386289951419969, 'bagging_freq': 7, 'min_child_samples': 32, 'scale_pos_weight': 1.9001590155445105}. Best is trial 0 with value: 0.0290698276501323.
# Evaluating features (current best: 0):  45%|████▌     | 56/124 [00:45<00:59,  1.14it/s][I 2024-09-11 08:35:51,289] A new study created in memory with name: no-name-dc28b8e7-20b8-468c-85cf-0fc640613285
# [I 2024-09-11 08:35:51,916] Trial 0 finished with value: 0.02415353874989496 and parameters: {'lambda_l1': 0.02344931952240738, 'lambda_l2': 0.013716350247892806, 'learning_rate': 0.04172864443280719, 'max_depth': 5, 'num_leaves': 29, 'colsample_bytree': 0.8580168027929385, 'colsample_bynode': 0.9474397773465477, 'bagging_fraction': 0.4856388591433847, 'bagging_freq': 4, 'min_child_samples': 25, 'scale_pos_weight': 2.1672811247465633}. Best is trial 0 with value: 0.02415353874989496.
# Evaluating features (current best: 0):  46%|████▌     | 57/124 [00:45<00:53,  1.25it/s][I 2024-09-11 08:35:51,921] A new study created in memory with name: no-name-214a25e3-28ce-4352-b88a-fc3cc960ebd9
# [I 2024-09-11 08:35:52,646] Trial 0 finished with value: 0.044311987106291195 and parameters: {'lambda_l1': 7.069170216197284, 'lambda_l2': 0.04718861912275908, 'learning_rate': 0.026376056490645606, 'max_depth': 8, 'num_leaves': 203, 'colsample_bytree': 0.5550799405875657, 'colsample_bynode': 0.46180216867142543, 'bagging_fraction': 0.7179764990995443, 'bagging_freq': 5, 'min_child_samples': 9, 'scale_pos_weight': 3.5502439746080174}. Best is trial 0 with value: 0.044311987106291195.
# Evaluating features (current best: 0):  47%|████▋     | 58/124 [00:46<00:51,  1.28it/s][I 2024-09-11 08:35:52,650] A new study created in memory with name: no-name-d6e54d10-4f29-41ed-b126-25c91a5fc4f0
# [I 2024-09-11 08:35:53,779] Trial 0 finished with value: 0.037074188300428815 and parameters: {'lambda_l1': 0.0023077986615456497, 'lambda_l2': 0.8708092353213774, 'learning_rate': 0.07793314194457635, 'max_depth': 8, 'num_leaves': 97, 'colsample_bytree': 0.5123323662523693, 'colsample_bynode': 0.5258845551451754, 'bagging_fraction': 0.7628231026521655, 'bagging_freq': 7, 'min_child_samples': 8, 'scale_pos_weight': 3.9424178243689925}. Best is trial 0 with value: 0.037074188300428815.
# Evaluating features (current best: 0):  48%|████▊     | 59/124 [00:47<00:57,  1.13it/s][I 2024-09-11 08:35:53,783] A new study created in memory with name: no-name-ecf9ba05-8513-4f03-a86b-aed53066e362
# [I 2024-09-11 08:35:54,467] Trial 0 finished with value: 0.026920049470507655 and parameters: {'lambda_l1': 0.003789375906446309, 'lambda_l2': 0.006169105755400913, 'learning_rate': 0.08739871054900537, 'max_depth': 5, 'num_leaves': 55, 'colsample_bytree': 0.9576940261631433, 'colsample_bynode': 0.7768475674562294, 'bagging_fraction': 0.6470140632855369, 'bagging_freq': 3, 'min_child_samples': 44, 'scale_pos_weight': 3.9539062779812193}. Best is trial 0 with value: 0.026920049470507655.
# Evaluating features (current best: 0):  48%|████▊     | 60/124 [00:48<00:52,  1.21it/s][I 2024-09-11 08:35:54,472] A new study created in memory with name: no-name-eed9e578-3ee0-435c-b490-f231bc06a346
# [I 2024-09-11 08:35:55,267] Trial 0 finished with value: 0.021019928007858422 and parameters: {'lambda_l1': 0.13955628672717252, 'lambda_l2': 0.002813091895753919, 'learning_rate': 0.02877612259085646, 'max_depth': 7, 'num_leaves': 219, 'colsample_bytree': 0.6131030286664787, 'colsample_bynode': 0.5704399484933782, 'bagging_fraction': 0.755070448663923, 'bagging_freq': 6, 'min_child_samples': 75, 'scale_pos_weight': 1.226435784937657}. Best is trial 0 with value: 0.021019928007858422.
# Evaluating features (current best: 0):  49%|████▉     | 61/124 [00:49<00:51,  1.22it/s][I 2024-09-11 08:35:55,272] A new study created in memory with name: no-name-c649a6fe-3dd7-4130-adfb-995718132fc0
# [I 2024-09-11 08:35:55,912] Trial 0 finished with value: 0.023775227240600744 and parameters: {'lambda_l1': 0.0018649763976257086, 'lambda_l2': 0.03934174950803816, 'learning_rate': 0.018216315040778114, 'max_depth': 5, 'num_leaves': 245, 'colsample_bytree': 0.47993869529296085, 'colsample_bynode': 0.9519786191842604, 'bagging_fraction': 0.919711271760481, 'bagging_freq': 6, 'min_child_samples': 47, 'scale_pos_weight': 2.7265415716711754}. Best is trial 0 with value: 0.023775227240600744.
# Evaluating features (current best: 0):  50%|█████     | 62/124 [00:49<00:47,  1.30it/s][I 2024-09-11 08:35:55,916] A new study created in memory with name: no-name-29f6c69e-39ad-43d5-a3b5-50769510324f
# [I 2024-09-11 08:35:57,034] Trial 0 finished with value: 0.03252520653587009 and parameters: {'lambda_l1': 0.6933403817810541, 'lambda_l2': 0.004987110989310221, 'learning_rate': 0.044128602034562016, 'max_depth': 7, 'num_leaves': 164, 'colsample_bytree': 0.41670858400109867, 'colsample_bynode': 0.40046245294754346, 'bagging_fraction': 0.6170208573963176, 'bagging_freq': 1, 'min_child_samples': 21, 'scale_pos_weight': 2.6684037873485345}. Best is trial 0 with value: 0.03252520653587009.
# Evaluating features (current best: 0):  51%|█████     | 63/124 [00:50<00:53,  1.14it/s][I 2024-09-11 08:35:57,039] A new study created in memory with name: no-name-ce6913e8-6528-4367-902d-39f8e9d1a58b
# [I 2024-09-11 08:35:57,930] Trial 0 finished with value: 0.030567543231749622 and parameters: {'lambda_l1': 1.8006777576342545, 'lambda_l2': 0.7484219846621646, 'learning_rate': 0.012764377581169441, 'max_depth': 5, 'num_leaves': 91, 'colsample_bytree': 0.44009418565144476, 'colsample_bynode': 0.5574076893183709, 'bagging_fraction': 0.9717880171870791, 'bagging_freq': 6, 'min_child_samples': 76, 'scale_pos_weight': 2.0033591543531877}. Best is trial 0 with value: 0.030567543231749622.
# Evaluating features (current best: 0):  52%|█████▏    | 64/124 [00:51<00:52,  1.14it/s][I 2024-09-11 08:35:57,938] A new study created in memory with name: no-name-5b589a24-549c-4ebd-9543-4358dec46881
# [I 2024-09-11 08:35:58,748] Trial 0 finished with value: 0.07047315368467033 and parameters: {'lambda_l1': 0.8923961643510127, 'lambda_l2': 1.4815993570727841, 'learning_rate': 0.0320862501650146, 'max_depth': 4, 'num_leaves': 54, 'colsample_bytree': 0.776364452967084, 'colsample_bynode': 0.8851534450498975, 'bagging_fraction': 0.8022151810124452, 'bagging_freq': 4, 'min_child_samples': 52, 'scale_pos_weight': 3.54869791778314}. Best is trial 0 with value: 0.07047315368467033.
# Evaluating features (current best: 0):  52%|█████▏    | 65/124 [00:52<00:50,  1.16it/s][I 2024-09-11 08:35:58,756] A new study created in memory with name: no-name-0b85e118-00b8-49fe-bca4-87e52205614d
# [I 2024-09-11 08:35:59,701] Trial 0 finished with value: 0.029823608409682578 and parameters: {'lambda_l1': 0.03319425421411443, 'lambda_l2': 0.06105696531548476, 'learning_rate': 0.017741043582208446, 'max_depth': 8, 'num_leaves': 150, 'colsample_bytree': 0.46511423257242107, 'colsample_bynode': 0.5633124967951942, 'bagging_fraction': 0.5137042669066076, 'bagging_freq': 6, 'min_child_samples': 90, 'scale_pos_weight': 1.2375704582231783}. Best is trial 0 with value: 0.029823608409682578.
# Evaluating features (current best: 0):  53%|█████▎    | 66/124 [00:53<00:51,  1.13it/s][I 2024-09-11 08:35:59,708] A new study created in memory with name: no-name-e85d4b16-78f3-427f-9d7e-9ac72b2355f4
# [I 2024-09-11 08:36:00,672] Trial 0 finished with value: 0.024741405114529068 and parameters: {'lambda_l1': 0.011255290610732924, 'lambda_l2': 0.006444499654643168, 'learning_rate': 0.08753424385493078, 'max_depth': 8, 'num_leaves': 140, 'colsample_bytree': 0.9106609293062297, 'colsample_bynode': 0.7851059781153815, 'bagging_fraction': 0.6871497982113676, 'bagging_freq': 3, 'min_child_samples': 50, 'scale_pos_weight': 3.7641244667374663}. Best is trial 0 with value: 0.024741405114529068.
# Evaluating features (current best: 0):  54%|█████▍    | 67/124 [00:54<00:52,  1.10it/s][I 2024-09-11 08:36:00,680] A new study created in memory with name: no-name-902614bb-5632-4dc8-9ff8-b9a49f82be63
# [I 2024-09-11 08:36:01,313] Trial 0 finished with value: 0.02362961176774464 and parameters: {'lambda_l1': 0.054306062432607806, 'lambda_l2': 0.0034980623102948603, 'learning_rate': 0.010266705196380095, 'max_depth': 6, 'num_leaves': 18, 'colsample_bytree': 0.6505626342006838, 'colsample_bynode': 0.7325408788208372, 'bagging_fraction': 0.7462718927092904, 'bagging_freq': 1, 'min_child_samples': 99, 'scale_pos_weight': 3.985997624117741}. Best is trial 0 with value: 0.02362961176774464.
# Evaluating features (current best: 0):  55%|█████▍    | 68/124 [00:55<00:46,  1.20it/s][I 2024-09-11 08:36:01,322] A new study created in memory with name: no-name-17b83ab0-bb23-434e-b83e-b59e4a7673cf
# [I 2024-09-11 08:36:02,148] Trial 0 finished with value: 0.02383090006676688 and parameters: {'lambda_l1': 0.001688062074065073, 'lambda_l2': 1.9634716638852228, 'learning_rate': 0.09302874675136819, 'max_depth': 6, 'num_leaves': 49, 'colsample_bytree': 0.539174155892094, 'colsample_bynode': 0.8311871659980836, 'bagging_fraction': 0.819510946043249, 'bagging_freq': 3, 'min_child_samples': 28, 'scale_pos_weight': 2.677481136313946}. Best is trial 0 with value: 0.02383090006676688.
# Evaluating features (current best: 0):  56%|█████▌    | 69/124 [00:55<00:45,  1.20it/s][I 2024-09-11 08:36:02,153] A new study created in memory with name: no-name-242bd143-a503-4485-99f3-2761254f081a
# ...
# [I 2024-09-11 09:06:11,921] Trial 0 finished with value: 0.1593205103249347 and parameters: {'lambda_l1': 0.21333866383771719, 'lambda_l2': 1.9153574405179594, 'learning_rate': 0.019931927998054565, 'max_depth': 5, 'num_leaves': 102, 'colsample_bytree': 0.8333191693013247, 'colsample_bynode': 0.6185924416103635, 'bagging_fraction': 0.6270255166021941, 'bagging_freq': 2, 'min_child_samples': 67, 'scale_pos_weight': 2.3945793250663963}. Best is trial 0 with value: 0.1593205103249347.
# Evaluating features (current best: 14):  81%|████████  | 89/110 [02:00<00:26,  1.25s/it][I 2024-09-11 09:06:11,926] A new study created in memory with name: no-name-58c26796-7a60-4301-8e9d-e99c1ca0cd44
# [I 2024-09-11 09:06:14,047] Trial 0 finished with value: 0.16369199585082866 and parameters: {'lambda_l1': 0.018304265819754785, 'lambda_l2': 0.44265394992637563, 'learning_rate': 0.02246988086719113, 'max_depth': 8, 'num_leaves': 173, 'colsample_bytree': 0.44306781673111295, 'colsample_bynode': 0.9360540549514642, 'bagging_fraction': 0.9301525011307733, 'bagging_freq': 2, 'min_child_samples': 13, 'scale_pos_weight': 2.2792330352055696}. Best is trial 0 with value: 0.16369199585082866.
# Evaluating features (current best: 14):  82%|████████▏ | 90/110 [02:02<00:30,  1.51s/it][I 2024-09-11 09:06:14,051] A new study created in memory with name: no-name-a8d43f3a-22eb-4ece-9861-5e168175c619
# [I 2024-09-11 09:06:15,166] Trial 0 finished with value: 0.15657039587431387 and parameters: {'lambda_l1': 0.012833829870104441, 'lambda_l2': 0.005027851713888393, 'learning_rate': 0.010126654399593602, 'max_depth': 5, 'num_leaves': 158, 'colsample_bytree': 0.45690361045939676, 'colsample_bynode': 0.4469315418260521, 'bagging_fraction': 0.9591737086510151, 'bagging_freq': 5, 'min_child_samples': 42, 'scale_pos_weight': 1.3370500842875876}. Best is trial 0 with value: 0.15657039587431387.
# Evaluating features (current best: 14):  83%|████████▎ | 91/110 [02:03<00:26,  1.39s/it][I 2024-09-11 09:06:15,172] A new study created in memory with name: no-name-dcb9864b-d329-4d5d-8691-3253b1cc715e
# [I 2024-09-11 09:06:16,580] Trial 0 finished with value: 0.16451699803959202 and parameters: {'lambda_l1': 0.056174681691312164, 'lambda_l2': 0.00208551684026053, 'learning_rate': 0.03725416874822822, 'max_depth': 6, 'num_leaves': 93, 'colsample_bytree': 0.5416761481147485, 'colsample_bynode': 0.931169189513977, 'bagging_fraction': 0.8734039453440863, 'bagging_freq': 6, 'min_child_samples': 37, 'scale_pos_weight': 3.6911954576427313}. Best is trial 0 with value: 0.16451699803959202.
# Evaluating features (current best: 14):  84%|████████▎ | 92/110 [02:05<00:25,  1.40s/it][I 2024-09-11 09:06:16,590] A new study created in memory with name: no-name-d515a78b-ec98-4973-bb68-35d7f9c9d623
# [I 2024-09-11 09:06:18,112] Trial 0 finished with value: 0.1581905193094162 and parameters: {'lambda_l1': 0.7780538044386984, 'lambda_l2': 0.2237140831451252, 'learning_rate': 0.01639362561352095, 'max_depth': 8, 'num_leaves': 55, 'colsample_bytree': 0.4424353406328518, 'colsample_bynode': 0.5004417970842693, 'bagging_fraction': 0.4711030843413075, 'bagging_freq': 5, 'min_child_samples': 48, 'scale_pos_weight': 1.0221135884425463}. Best is trial 0 with value: 0.1581905193094162.
# Evaluating features (current best: 14):  85%|████████▍ | 93/110 [02:06<00:24,  1.44s/it][I 2024-09-11 09:06:18,118] A new study created in memory with name: no-name-e0e2f5e2-b705-4d9e-b98c-bdaab3941ad8
# [I 2024-09-11 09:06:19,892] Trial 0 finished with value: 0.16168038918484115 and parameters: {'lambda_l1': 0.13858684606305888, 'lambda_l2': 0.09484278817949972, 'learning_rate': 0.03736829428065097, 'max_depth': 4, 'num_leaves': 159, 'colsample_bytree': 0.920290389974699, 'colsample_bynode': 0.6523201694222394, 'bagging_fraction': 0.8853750614284298, 'bagging_freq': 4, 'min_child_samples': 9, 'scale_pos_weight': 3.8134621556804493}. Best is trial 0 with value: 0.16168038918484115.
# Evaluating features (current best: 14):  85%|████████▌ | 94/110 [02:08<00:24,  1.54s/it][I 2024-09-11 09:06:19,898] A new study created in memory with name: no-name-ff1402c5-9fc6-4fe7-8563-289c6db9fa79
# [I 2024-09-11 09:06:20,934] Trial 0 finished with value: 0.16268071076684426 and parameters: {'lambda_l1': 0.011429000460494523, 'lambda_l2': 0.23066686999328506, 'learning_rate': 0.06762298399766496, 'max_depth': 4, 'num_leaves': 45, 'colsample_bytree': 0.9470136238655578, 'colsample_bynode': 0.824115176717197, 'bagging_fraction': 0.9295102043336388, 'bagging_freq': 7, 'min_child_samples': 90, 'scale_pos_weight': 2.7800358676292842}. Best is trial 0 with value: 0.16268071076684426.
# Evaluating features (current best: 14):  86%|████████▋ | 95/110 [02:09<00:20,  1.39s/it][I 2024-09-11 09:06:20,939] A new study created in memory with name: no-name-20e4465d-ddcb-4f5b-adc7-76535a27488d
# [I 2024-09-11 09:06:21,995] Trial 0 finished with value: 0.16646386096270044 and parameters: {'lambda_l1': 0.5899354792702494, 'lambda_l2': 0.019876037634047952, 'learning_rate': 0.056441140920442584, 'max_depth': 5, 'num_leaves': 255, 'colsample_bytree': 0.4502703407722093, 'colsample_bynode': 0.7844537429687559, 'bagging_fraction': 0.9535978209226428, 'bagging_freq': 3, 'min_child_samples': 80, 'scale_pos_weight': 3.0464140108039732}. Best is trial 0 with value: 0.16646386096270044.
# Evaluating features (current best: 14):  87%|████████▋ | 96/110 [02:10<00:18,  1.29s/it][I 2024-09-11 09:06:22,005] A new study created in memory with name: no-name-6f735b25-6935-4e2c-bf6c-43d75f6b360b
# [I 2024-09-11 09:06:23,506] Trial 0 finished with value: 0.1574179239396127 and parameters: {'lambda_l1': 0.34769278775635215, 'lambda_l2': 0.18893216419515313, 'learning_rate': 0.011852801671691103, 'max_depth': 5, 'num_leaves': 51, 'colsample_bytree': 0.911333951744176, 'colsample_bynode': 0.5331399116680234, 'bagging_fraction': 0.8404733292107508, 'bagging_freq': 3, 'min_child_samples': 15, 'scale_pos_weight': 1.196067027646574}. Best is trial 0 with value: 0.1574179239396127.
# Evaluating features (current best: 14):  88%|████████▊ | 97/110 [02:12<00:17,  1.36s/it][I 2024-09-11 09:06:23,512] A new study created in memory with name: no-name-3530dbb5-6cf8-4bf2-855e-0bbda99a0443
# [I 2024-09-11 09:06:24,349] Trial 0 finished with value: 0.16198994763952065 and parameters: {'lambda_l1': 0.001910827286715052, 'lambda_l2': 0.0011355551551417663, 'learning_rate': 0.03746385760684881, 'max_depth': 4, 'num_leaves': 53, 'colsample_bytree': 0.5320308140966018, 'colsample_bynode': 0.9391260551959862, 'bagging_fraction': 0.6064284241376641, 'bagging_freq': 1, 'min_child_samples': 32, 'scale_pos_weight': 3.2492202005166524}. Best is trial 0 with value: 0.16198994763952065.
# Evaluating features (current best: 14):  89%|████████▉ | 98/110 [02:12<00:14,  1.20s/it][I 2024-09-11 09:06:24,354] A new study created in memory with name: no-name-bed543d9-6847-4336-b26f-e5dbe2461a7f
# [I 2024-09-11 09:06:25,708] Trial 0 finished with value: 0.16327371723198783 and parameters: {'lambda_l1': 0.06415474850088547, 'lambda_l2': 0.03333732262087219, 'learning_rate': 0.08076257685454218, 'max_depth': 8, 'num_leaves': 226, 'colsample_bytree': 0.4833400702953916, 'colsample_bynode': 0.9979938782797757, 'bagging_fraction': 0.5268037881957178, 'bagging_freq': 6, 'min_child_samples': 52, 'scale_pos_weight': 1.537001377229225}. Best is trial 0 with value: 0.16327371723198783.
# Evaluating features (current best: 14):  90%|█████████ | 99/110 [02:14<00:13,  1.25s/it][I 2024-09-11 09:06:25,714] A new study created in memory with name: no-name-a5fcf5b0-da0b-4e2a-b3d2-566e466184a1
# [I 2024-09-11 09:06:26,814] Trial 0 finished with value: 0.1646544981102493 and parameters: {'lambda_l1': 4.966033854492738, 'lambda_l2': 0.02417663022149552, 'learning_rate': 0.0398736402744961, 'max_depth': 5, 'num_leaves': 186, 'colsample_bytree': 0.46957598524918576, 'colsample_bynode': 0.9153389991878635, 'bagging_fraction': 0.9478850869813765, 'bagging_freq': 4, 'min_child_samples': 48, 'scale_pos_weight': 2.739211010274661}. Best is trial 0 with value: 0.1646544981102493.
# Evaluating features (current best: 14):  91%|█████████ | 100/110 [02:15<00:12,  1.21s/it][I 2024-09-11 09:06:26,819] A new study created in memory with name: no-name-7b0a2817-f44b-45c7-b817-6a04739ee854
# [I 2024-09-11 09:06:27,893] Trial 0 finished with value: 0.16009096614428298 and parameters: {'lambda_l1': 7.294756200106564, 'lambda_l2': 0.0028220694025334996, 'learning_rate': 0.040209780651810696, 'max_depth': 6, 'num_leaves': 109, 'colsample_bytree': 0.687184239441949, 'colsample_bynode': 0.8135958477610912, 'bagging_fraction': 0.6769906878389667, 'bagging_freq': 4, 'min_child_samples': 82, 'scale_pos_weight': 1.8871204266006758}. Best is trial 0 with value: 0.16009096614428298.
# Evaluating features (current best: 14):  92%|█████████▏| 101/110 [02:16<00:10,  1.17s/it][I 2024-09-11 09:06:27,898] A new study created in memory with name: no-name-dcbc81eb-6e0e-418a-9e40-3be73aa9007c
# [I 2024-09-11 09:06:29,423] Trial 0 finished with value: 0.1637097651871739 and parameters: {'lambda_l1': 0.17026395750067227, 'lambda_l2': 0.03523858303477262, 'learning_rate': 0.08867724137803085, 'max_depth': 5, 'num_leaves': 153, 'colsample_bytree': 0.9134341744285325, 'colsample_bynode': 0.7563842392759677, 'bagging_fraction': 0.9699388502894194, 'bagging_freq': 6, 'min_child_samples': 16, 'scale_pos_weight': 1.8986243963961862}. Best is trial 0 with value: 0.1637097651871739.
# Evaluating features (current best: 14):  93%|█████████▎| 102/110 [02:18<00:10,  1.28s/it][I 2024-09-11 09:06:29,428] A new study created in memory with name: no-name-b23f877f-97cc-4905-a8a0-7f38c4dfceea
# [I 2024-09-11 09:06:31,114] Trial 0 finished with value: 0.16424396644980171 and parameters: {'lambda_l1': 4.40643358250202, 'lambda_l2': 0.016663569204392333, 'learning_rate': 0.058126063383431084, 'max_depth': 6, 'num_leaves': 168, 'colsample_bytree': 0.8975185000121961, 'colsample_bynode': 0.7670487087202582, 'bagging_fraction': 0.6929886922217852, 'bagging_freq': 5, 'min_child_samples': 81, 'scale_pos_weight': 2.2063085899572314}. Best is trial 0 with value: 0.16424396644980171.
# Evaluating features (current best: 14):  94%|█████████▎| 103/110 [02:19<00:09,  1.40s/it][I 2024-09-11 09:06:31,119] A new study created in memory with name: no-name-0cdc0fed-913a-4f98-9d3b-47340174039b
# [I 2024-09-11 09:06:32,492] Trial 0 finished with value: 0.15778196739427214 and parameters: {'lambda_l1': 8.604121220175946, 'lambda_l2': 0.0031771086057766156, 'learning_rate': 0.0233747034446759, 'max_depth': 6, 'num_leaves': 172, 'colsample_bytree': 0.4480725102493303, 'colsample_bynode': 0.5841594583874522, 'bagging_fraction': 0.6005961648204161, 'bagging_freq': 4, 'min_child_samples': 54, 'scale_pos_weight': 2.186192637994209}. Best is trial 0 with value: 0.15778196739427214.
# Evaluating features (current best: 14):  95%|█████████▍| 104/110 [02:21<00:08,  1.40s/it][I 2024-09-11 09:06:32,499] A new study created in memory with name: no-name-71a305b8-4a0c-42bb-b4ce-42ed58b1e1e1
# [I 2024-09-11 09:06:33,949] Trial 0 finished with value: 0.16564455818459725 and parameters: {'lambda_l1': 0.36932885164403495, 'lambda_l2': 0.36184931036279805, 'learning_rate': 0.055113680934920285, 'max_depth': 8, 'num_leaves': 18, 'colsample_bytree': 0.5310491469320908, 'colsample_bynode': 0.4486200832324415, 'bagging_fraction': 0.9176789930185743, 'bagging_freq': 1, 'min_child_samples': 55, 'scale_pos_weight': 2.8412346628633633}. Best is trial 0 with value: 0.16564455818459725.
# Evaluating features (current best: 14):  95%|█████████▌| 105/110 [02:22<00:07,  1.41s/it][I 2024-09-11 09:06:33,953] A new study created in memory with name: no-name-d4580d93-558d-421d-a1a3-b2d76ec77799
# [I 2024-09-11 09:06:34,951] Trial 0 finished with value: 0.15958032466161415 and parameters: {'lambda_l1': 0.0918070848184516, 'lambda_l2': 4.907601685671016, 'learning_rate': 0.02640547945479985, 'max_depth': 4, 'num_leaves': 98, 'colsample_bytree': 0.794583930700135, 'colsample_bynode': 0.8193033470138829, 'bagging_fraction': 0.7623740245636026, 'bagging_freq': 5, 'min_child_samples': 32, 'scale_pos_weight': 3.8320960790530494}. Best is trial 0 with value: 0.15958032466161415.
# Evaluating features (current best: 14):  96%|█████████▋| 106/110 [02:23<00:05,  1.29s/it][I 2024-09-11 09:06:34,956] A new study created in memory with name: no-name-2f258e4b-eba3-4e4c-b449-2cb208dc3cf3
# [I 2024-09-11 09:06:36,645] Trial 0 finished with value: 0.16041767343256247 and parameters: {'lambda_l1': 0.03184159541356385, 'lambda_l2': 0.00961874244017019, 'learning_rate': 0.012397002788590347, 'max_depth': 7, 'num_leaves': 59, 'colsample_bytree': 0.6636895879045692, 'colsample_bynode': 0.6994534243405837, 'bagging_fraction': 0.5989445248243888, 'bagging_freq': 7, 'min_child_samples': 21, 'scale_pos_weight': 3.4743219848749165}. Best is trial 0 with value: 0.16041767343256247.
# Evaluating features (current best: 14):  97%|█████████▋| 107/110 [02:25<00:04,  1.41s/it][I 2024-09-11 09:06:36,652] A new study created in memory with name: no-name-81db0395-e8e9-49be-be19-fdfdeab78862
# [I 2024-09-11 09:06:37,686] Trial 0 finished with value: 0.16116780972376119 and parameters: {'lambda_l1': 2.030313793492403, 'lambda_l2': 0.2622706346134828, 'learning_rate': 0.0315299596310016, 'max_depth': 4, 'num_leaves': 166, 'colsample_bytree': 0.7690649655161444, 'colsample_bynode': 0.7842332928939719, 'bagging_fraction': 0.907368264998934, 'bagging_freq': 4, 'min_child_samples': 64, 'scale_pos_weight': 3.4664758809019434}. Best is trial 0 with value: 0.16116780972376119.
# Evaluating features (current best: 14):  98%|█████████▊| 108/110 [02:26<00:02,  1.30s/it][I 2024-09-11 09:06:37,693] A new study created in memory with name: no-name-a3681568-5531-4956-b3e5-0a2109172e26
# [I 2024-09-11 09:06:38,785] Trial 0 finished with value: 0.164789859151485 and parameters: {'lambda_l1': 3.788962934002909, 'lambda_l2': 0.002332459211258278, 'learning_rate': 0.06677168848460266, 'max_depth': 5, 'num_leaves': 194, 'colsample_bytree': 0.7338426905222563, 'colsample_bynode': 0.48788120151058284, 'bagging_fraction': 0.5265961647165448, 'bagging_freq': 7, 'min_child_samples': 58, 'scale_pos_weight': 1.9563540950044793}. Best is trial 0 with value: 0.164789859151485.
# Evaluating features (current best: 14):  99%|█████████▉| 109/110 [02:27<00:01,  1.24s/it][I 2024-09-11 09:06:38,795] A new study created in memory with name: no-name-230c2dd8-3896-43c2-ad85-34c26000e193
# [I 2024-09-11 09:06:40,253] Trial 0 finished with value: 0.16476762110064275 and parameters: {'lambda_l1': 0.13038107293889173, 'lambda_l2': 5.607459172511605, 'learning_rate': 0.062322273140012895, 'max_depth': 8, 'num_leaves': 232, 'colsample_bytree': 0.472777112352705, 'colsample_bynode': 0.6427590515575624, 'bagging_fraction': 0.9868135374956815, 'bagging_freq': 4, 'min_child_samples': 79, 'scale_pos_weight': 2.2629574806290833}. Best is trial 0 with value: 0.16476762110064275.
# Evaluating features (current best: 14): 100%|██████████| 110/110 [02:28<00:00,  1.35s/it]
# Stopping: No improvement (best overall: 0.1680, current best: 0.1665)
#
# Final best feature combination:
# 1. clin_size_long_diam_mm
# 2. tbp_lv_H_between_std
# 3. lesion_visibility_score
# 4. tbp_lv_deltaLBnorm_between_std
# 5. age_approx_zscore
# 6. tbp_lv_B
# 7. avg_contrast
# 8. hue_contrast
# 9. anatom_site_general_encoded
# 10. attribution_encoded
# 11. tbp_lv_C
# 12. tbp_lv_nevi_confidence_between_std
# 13. tbp_lv_B_between_std
# 14. tbp_lv_Aext
# Best overall score: 0.1680
# Best feature combination: ['clin_size_long_diam_mm', 'tbp_lv_H_between_std', 'lesion_visibility_score', 'tbp_lv_deltaLBnorm_between_std', 'age_approx_zscore', 'tbp_lv_B', 'avg_contrast', 'hue_contrast', 'anatom_site_general_encoded', 'attribution_encoded', 'tbp_lv_C', 'tbp_lv_nevi_confidence_between_std', 'tbp_lv_B_between_std', 'tbp_lv_Aext']

# %%
df_train[best_features].to_csv('df_train_filter.csv', index = False)
